# %% [markdown]
# ## Groupby() and  Aggregate, filter, transform, apply

# %% [markdown]
# # GroupBy: Split, Apply, Combine
#
#
# Groupby() is used to make groups of any column in our dataset by passing the column name in groupby ().
#
# The groupby function basically work on  these three  Split, Apply, Combine .
#
# Split:-The split step involves breaking up and grouping a DataFrame depending on the
# value of the specified key.
#
# Apply:-The apply step involves computing some function, usually an aggregate, transfor‐
# mation, or filtering, within the individual groups.
#
# Combine:-The combine step merges the results of these operations into an output array.

# %%
# reading the csv file
import pandas as pd
ipl=pd.read_csv('IPL2023_Batsman.csv',encoding='windows-1252')
ipl.head()
# Out:
#    match_no          Batsman                 team  Run  Ball  4s  6s  \
# 0         1     Devon Conway  Chennai Super Kings    1     6   0   0
# 1         1  Ruturaj Gaikwad  Chennai Super Kings   92    50   4   9
# 2         1        Moeen Ali  Chennai Super Kings   23    17   4   1
# 3         1       Ben Stokes  Chennai Super Kings    7     6   1   0
# 4         1    Ambati Rayudu  Chennai Super Kings   12    12   0   1
#
#            out_by
# 0  Mohammed Shami
# 1  Alzarri Joseph
# 2     Rashid Khan
# 3     Rashid Khan
# 4   Joshua Little

# %%
# renaming  the columns name 
ipl.rename(columns={'4s':'Fours',
                    '6s':'Sixes',
                   'out_by':'Wicket taken by'},inplace=True)

# %%
ipl.head()
# Out:
#    match_no          Batsman                 team  Run  Ball  Fours  Sixes  \
# 0         1     Devon Conway  Chennai Super Kings    1     6      0      0
# 1         1  Ruturaj Gaikwad  Chennai Super Kings   92    50      4      9
# 2         1        Moeen Ali  Chennai Super Kings   23    17      4      1
# 3         1       Ben Stokes  Chennai Super Kings    7     6      1      0
# 4         1    Ambati Rayudu  Chennai Super Kings   12    12      0      1
#
#   Wicket taken by
# 0  Mohammed Shami
# 1  Alzarri Joseph
# 2     Rashid Khan
# 3     Rashid Khan
# 4   Joshua Little

# %%
# check in the column names of the dataset 
ipl.columns
# Out:
# Index(['match_no', 'Batsman', 'team', 'Run', 'Ball', 'Fours', 'Sixes',
#        'Wicket taken by'],
#       dtype='object')

# %%
# checking the index of data set
ipl.index
# Out:
# RangeIndex(start=0, stop=1114, step=1)

# %%
ipl.shape
# Out:
# (1114, 8)

# %%
ipl.size
# Out:
# 8912

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1114 entries, 0 to 1113
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   match_no         1114 non-null   int64
#  1   Batsman          1114 non-null   object
#  2   team             1114 non-null   object
#  3   Run              1114 non-null   int64
#  4   Ball             1114 non-null   int64
#  5   Fours            1114 non-null   int64
#  6   Sixes            1114 non-null   int64
#  7   Wicket taken by  1114 non-null   object
# dtypes: int64(5), object(3)
# memory usage: 69.8+ KB

# %%
ipl.describe()
# Out:
#           match_no          Run         Ball        Fours        Sixes
# count  1114.000000  1114.000000  1114.000000  1114.000000  1114.000000
# mean     34.609515    20.733393    14.648115     1.847397     0.951526
# std      20.049515    22.933746    13.582402     2.496009     1.574557
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%      17.250000     3.000000     4.000000     0.000000     0.000000
# 50%      34.000000    12.000000    10.000000     1.000000     0.000000
# 75%      52.000000    30.000000    21.000000     3.000000     1.000000
# max      70.000000   124.000000    66.000000    16.000000    10.000000

# %%
# making row index of column match_no
ipl.set_index('match_no',inplace=True)

# %%
ipl.head()
# Out:
#                   Batsman                 team  Run  Ball  Fours  Sixes  \
# match_no
# 1            Devon Conway  Chennai Super Kings    1     6      0      0
# 1         Ruturaj Gaikwad  Chennai Super Kings   92    50      4      9
# 1               Moeen Ali  Chennai Super Kings   23    17      4      1
# 1              Ben Stokes  Chennai Super Kings    7     6      1      0
# 1           Ambati Rayudu  Chennai Super Kings   12    12      0      1
#
#          Wicket taken by
# match_no
# 1         Mohammed Shami
# 1         Alzarri Joseph
# 1            Rashid Khan
# 1            Rashid Khan
# 1          Joshua Little

# %%
# performing the grouby () to team column 
ipl.groupby('Batsman')

# %% [raw]
# We can compute the most basic split-apply-combine operation with the groupby()
# method of DataFrames, passing the name of the desired Batsman column:

# %%
ipl.groupby('Batsman')

# %% [raw]
# By applying groupby function we can not see dataframe because groupby () take in object only ,if we have have to see dataframe then we must have to apply atleast one aggregate function such as sum(),max() etc.

# %% [markdown]
# # Column indexing
#
# The GroupBy object supports column indexing in the same way as
# the DataFrame, and returns a modified GroupBy object.
#
# its modified groupby object into series group

# %%
# taking another column from cups dataset 
ipl.groupby('Batsman')['team']

# %% [raw]
# Here we’ve selected a particular Series group from the original DataFrame group by reference to its column name.
# As we know the GroupBy object, no computation is done until we call some aggregate on the object:

# %%
# Taking the aggregate method to perform some arthmetic operation like ,min ,sum etc.
# By performing the aggregate methods on object then only we can see grouping of the column, lets see below exaple

ipl.groupby('Batsman')['team'].max()
# Out:
# Batsman
# Abdul Basith                   Rajasthan Royals
# Abdul Samad                 Sunrisers Hyderabad
# Abhinav Manohar                  Gujarat Titans
# Abhishek Sharma             Sunrisers Hyderabad
# Abishek Porel                    Delhi Capitals
#                                ...
# Wayne Parnell       Royal Challengers Bangalore
# Wriddhiman Saha                  Gujarat Titans
# Yash Dhull                       Delhi Capitals
# Yashasvi Jaiswal               Rajasthan Royals
# Yudhvir Singh              Lucknow Super Giants
# Name: team, Length: 176, dtype: object

# %% [raw]
# As we mentioned earlier the GroupBy object supports column indexing in the same way as the DataFrame, and returns a modified GroupBy object into series.
#
# As we earlier mentioned above by perfoming aggregate method we can able to see grouping of data.

# %%
# showing the datatype
type(ipl.groupby('Batsman')['team'].max())
# Out:
# pandas.core.series.Series

# %% [raw]
# See as the data type is in  panda series

# %%
# counting the  total number of team in which the batsman have  been palyed using count aggregate .
ipl.groupby('Batsman')['team'].count()
# Out:
# Batsman
# Abdul Basith         1
# Abdul Samad          8
# Abhinav Manohar      6
# Abhishek Sharma     11
# Abishek Porel        4
#                     ..
# Wayne Parnell        1
# Wriddhiman Saha     14
# Yash Dhull           3
# Yashasvi Jaiswal    14
# Yudhvir Singh        2
# Name: team, Length: 176, dtype: int64

# %% [raw]
# In the above output  we clearly absorb that few player has been played fro one Team only like Wayne Parnell,Abdul Basith         1
# etc.

# %%
# adding all the team using sum aggregate
ipl.groupby('Batsman')['team'].sum()
# Out:
# Batsman
# Abdul Basith                                         Rajasthan Royals
# Abdul Samad         Sunrisers HyderabadSunrisers HyderabadSunriser...
# Abhinav Manohar     Gujarat TitansGujarat TitansGujarat TitansGuja...
# Abhishek Sharma     Sunrisers HyderabadSunrisers HyderabadSunriser...
# Abishek Porel       Delhi CapitalsDelhi CapitalsDelhi CapitalsDelh...
#                                           ...
# Wayne Parnell                             Royal Challengers Bangalore
# Wriddhiman Saha     Gujarat TitansGujarat TitansGujarat TitansGuja...
# Yash Dhull                 Delhi CapitalsDelhi CapitalsDelhi Capitals
# Yashasvi Jaiswal    Rajasthan RoyalsRajasthan RoyalsRajasthan Roya...
# Yudhvir Singh                Lucknow Super GiantsLucknow Super Giants
# Name: team, Length: 176, dtype: object

# %% [raw]
# If you compare the total nu. of teams and sum of the team we can clearly see the Wayne Parnell has played for Royal Challengers Bangalore
# and Abdul Basith has played for  Rajasthan Royals only in short they both have played for only one team

# %%
# fetching the highest run by a batsman in the ipl series 
ipl.groupby('Batsman')['Run'].sum().sort_values(ascending=False)
# Out:
# Batsman
# Faf du Plessis      730
# Shubman Gill        680
# Virat Kohli         639
# Yashasvi Jaiswal    625
# Ruturaj Gaikwad     581
#                    ...
# Riley Meredith        0
# Mohit Sharma          0
# Rahul Chahar          0
# Tushar Deshpande      0
# Mohammed Shami        0
# Name: Run, Length: 176, dtype: int64

# %%
# fetching the highest fours by a batsman
ipl.groupby('Batsman')['Fours'].sum().sort_values(ascending=False)
# Out:
# Batsman
# Yashasvi Jaiswal    83
# David Warner        69
# Shubman Gill        67
# Virat Kohli         65
# Faf du Plessis      60
#                     ..
# Nathan Ellis         0
# Noor Ahmad           0
# Rahul Chahar         0
# Riley Meredith       0
# Yudhvir Singh        0
# Name: Fours, Length: 176, dtype: int64

# %%
# fetching the highest six by a batsman
ipl.groupby('Batsman')['Sixes'].sum().sort_values(ascending=False)
# Out:
# Batsman
# Faf du Plessis     36
# Shivam Dube        33
# Glenn Maxwell      31
# Rinku Singh        29
# Ruturaj Gaikwad    29
#                    ..
# Kedar Jadhav        0
# Karn Sharma         0
# Karan Sharma        0
# Kagiso Rabada       0
# Yudhvir Singh       0
# Name: Sixes, Length: 176, dtype: int64

# %%
# fetching the highest ball played by a batsman
ipl.groupby('Batsman')['Ball'].sum().sort_values(ascending=False)
# Out:
# Batsman
# Faf du Plessis       475
# Virat Kohli          457
# Shubman Gill         446
# Ruturaj Gaikwad      397
# David Warner         392
#                     ...
# Romario Shepherd       1
# Mohammed Shami         1
# Mohit Sharma           1
# Mustafizur Rahman      1
# Abdul Basith           1
# Name: Ball, Length: 176, dtype: int64

# %%
# seeing the highest wicket taken by which player
ipl.groupby('Batsman')['Wicket taken by'].sum().sort_values(ascending=False)
# Out:
# Batsman
# Harry Brook          Yuzvendra ChahalRavi BishnoiArshdeep SinghNot ...
# Bhuvneshwar Kumar    Yuzvendra ChahalNot OutArjun TendulkarNot OutN...
# Mayank Agarwal       Yuzvendra ChahalKrunal PandyaRahul ChaharAndre...
# Adil Rashid                                Yuzvendra ChahalAmit Mishra
# Atharva Taide        Yudhvir SinghMohammed SirajPiyush ChawlaRavi B...
#                                            ...
# Ruturaj Gaikwad      Alzarri JosephRavi BishnoiNot OutSandeep Sharm...
# Ravindra Jadeja      Alzarri JosephMark WoodNot OutGlenn MaxwellKul...
# Vivrant Sharma                                           Akash Madhwal
# Rohit Sharma         Akash DeepTushar DeshpandeMustafizur RahmanSuy...
# Romario Shepherd                                           Adil Rashid
# Name: Wicket taken by, Length: 176, dtype: object

# %%
ipl.groupby('Batsman',sort=False)['Wicket taken by'].sum()
# Out:
# Batsman
# Devon Conway        Mohammed ShamiMark WoodJason BehrendorffYuzven...
# Ruturaj Gaikwad     Alzarri JosephRavi BishnoiNot OutSandeep Sharm...
# Moeen Ali           Rashid KhanRavi BishnoiAdam ZampaNot OutNot Ou...
# Ben Stokes                                      Rashid KhanAvesh Khan
# Ambati Rayudu       Joshua LittleNot OutNot OutYuzvendra ChahalVij...
#                                           ...
# Mohammed Shami                                      Bhuvneshwar Kumar
# Mohit Sharma                                                  Not Out
# Sanvir Singh                                      Mohit SharmaNot Out
# Fazalhaq Farooqi                                              Not Out
# Vivrant Sharma                                          Akash Madhwal
# Name: Wicket taken by, Length: 176, dtype: object

# %%
# putting the data  in ipl1 variable so we have to just call varible only instead of performing groupby everytime
ipl1=ipl.groupby('Batsman')
ipl1

# %% [markdown]
# # Iteration over groups
#
# The GroupBy object supports direct iteration over the groups, returning each group as a Series or DataFrame.
#
# If we have to see the result of how groupby works vizually that is in dataframe or in series  then we have to perform iteration over the groupby() and it support directly iteration.

# %%
# perfroming the Iteration over groups to see the how groupby computation look like
for batsman,batsman_df in ipl1:
    print(batsman)
    print(batsman_df)
# Out:
# Abdul Basith
#                Batsman              team  Run  Ball  Fours  Sixes  \
# match_no
# 32        Abdul Basith  Rajasthan Royals    1     1      0      0
#
#          Wicket taken by
# match_no
# 32               Not Out
# Abdul Samad
#               Batsman                 team  Run  Ball  Fours  Sixes  \
# match_no
# 4         Abdul Samad  Sunrisers Hyderabad   32    32      2      1
# 10        Abdul Samad  Sunrisers Hyderabad   21    10      1      2
# 25        Abdul Samad  Sunrisers Hyderabad    9    12      1      0
# 40        Abdul Samad  Sunrisers Hyderabad   28    21      1      2
# 47        Abdul Samad  Sunrisers Hyderabad   21    18      3      0
# 52        Abdul Samad  Sunrisers Hyderabad   17     7      0      2
# 58        Abdul Samad  Sunrisers Hyderabad   37    25      1      4
# 62        Abdul Samad  Sunrisers Hyderabad    4     3      1      0
#
#               Wicket taken by
# match_no
# 4                     Not Out
# 10                    Not Out
# ...

# %% [raw]
# As we see we have iterated our all the groupby data by iterating over it.

# %%
# we can acess one  specific datafamre with the help of  using get_groups() 
ipl1.get_group('Abdul Samad')
# Out:
#               Batsman                 team  Run  Ball  Fours  Sixes  \
# match_no
# 4         Abdul Samad  Sunrisers Hyderabad   32    32      2      1
# 10        Abdul Samad  Sunrisers Hyderabad   21    10      1      2
# 25        Abdul Samad  Sunrisers Hyderabad    9    12      1      0
# 40        Abdul Samad  Sunrisers Hyderabad   28    21      1      2
# 47        Abdul Samad  Sunrisers Hyderabad   21    18      3      0
# 52        Abdul Samad  Sunrisers Hyderabad   17     7      0      2
# 58        Abdul Samad  Sunrisers Hyderabad   37    25      1      4
# 62        Abdul Samad  Sunrisers Hyderabad    4     3      1      0
#
#               Wicket taken by
# match_no
# 4                     Not Out
# 10                    Not Out
# 25                    Run Out
# 40             Mitchell Marsh
# 47        Varun Chakaravarthy
# 52                    Not Out
# 58                    Not Out
# 62               Mohit Sharma

# %%
ipl1.get_group('MS Dhoni')
# Out:
#            Batsman                 team  Run  Ball  Fours  Sixes  \
# match_no
# 1         MS Dhoni  Chennai Super Kings   14     7      1      1
# 6         MS Dhoni  Chennai Super Kings   12     3      0      2
# 17        MS Dhoni  Chennai Super Kings   32    17      1      3
# 24        MS Dhoni  Chennai Super Kings    1     1      0      0
# 33        MS Dhoni  Chennai Super Kings    2     3      0      0
# 41        MS Dhoni  Chennai Super Kings   13     4      0      2
# 49        MS Dhoni  Chennai Super Kings    2     3      0      0
# 55        MS Dhoni  Chennai Super Kings   20     9      1      2
# 61        MS Dhoni  Chennai Super Kings    2     3      0      0
# 67        MS Dhoni  Chennai Super Kings    5     4      0      0
#
#          Wicket taken by
# match_no
# 1                Not Out
# 6              Mark Wood
# 17               Not Out
# 24               Not Out
# 33               Not Out
# 41               Not Out
# 49               Not Out
# ...

# %%
ipl1.get_group('Devon Conway')
# Out:
#                Batsman                 team  Run  Ball  Fours  Sixes  \
# match_no
# 1         Devon Conway  Chennai Super Kings    1     6      0      0
# 6         Devon Conway  Chennai Super Kings   47    29      5      2
# 12        Devon Conway  Chennai Super Kings    0     4      0      0
# 17        Devon Conway  Chennai Super Kings   50    38      6      0
# 24        Devon Conway  Chennai Super Kings   83    45      6      6
# 33        Devon Conway  Chennai Super Kings   56    40      4      3
# 37        Devon Conway  Chennai Super Kings    8    16      1      0
# 41        Devon Conway  Chennai Super Kings   92    52     16      1
# 49        Devon Conway  Chennai Super Kings   44    42      4      0
# 55        Devon Conway  Chennai Super Kings   10    13      1      0
# 61        Devon Conway  Chennai Super Kings   30    28      3      0
# 67        Devon Conway  Chennai Super Kings   87    52     11      3
#
#               Wicket taken by
# match_no
# ...

# %%
# we can perform agrgregate method on individuals batsman by using get_group method
ipl1.get_group('Devon Conway').sum()
# Out:
# Batsman            Devon ConwayDevon ConwayDevon ConwayDevon Conw...
# team               Chennai Super KingsChennai Super KingsChennai ...
# Run                                                              508
# Ball                                                             365
# Fours                                                             57
# Sixes                                                             15
# Wicket taken by    Mohammed ShamiMark WoodJason BehrendorffYuzven...
# dtype: object

# %%
# finding maximum best score  by Devon Conway in IPL 2023 season 
ipl1.get_group('Devon Conway').max()
# Out:
# Batsman                   Devon Conway
# team               Chennai Super Kings
# Run                                 92
# Ball                                52
# Fours                               16
# Sixes                                6
# Wicket taken by       Yuzvendra Chahal
# dtype: object

# %%
# finding min score  by Devon Conway in IPL 2023 season 
ipl1.get_group('Devon Conway').min()
# Out:
# Batsman                   Devon Conway
# team               Chennai Super Kings
# Run                                  0
# Ball                                 4
# Fours                                0
# Sixes                                0
# Wicket taken by             Adam Zampa
# dtype: object

# %%
# we can fetch some data of player Shikhar Dhawan 
ipl1.get_group('Shikhar Dhawan')
# Out:
#                  Batsman          team  Run  Ball  Fours  Sixes  \
# match_no
# 2         Shikhar Dhawan  Punjab Kings   40    29      6      0
# 8         Shikhar Dhawan  Punjab Kings   86    56      9      3
# 14        Shikhar Dhawan  Punjab Kings   99    66     12      5
# 18        Shikhar Dhawan  Punjab Kings    8     8      2      0
# 38        Shikhar Dhawan  Punjab Kings    1     2      0      0
# 41        Shikhar Dhawan  Punjab Kings   28    15      4      1
# 46        Shikhar Dhawan  Punjab Kings   30    20      5      0
# 53        Shikhar Dhawan  Punjab Kings   57    47      9      1
# 59        Shikhar Dhawan  Punjab Kings    7     5      0      1
# 64        Shikhar Dhawan  Punjab Kings    0     1      0      0
# 66        Shikhar Dhawan  Punjab Kings   17    12      2      1
#
#               Wicket taken by
# match_no
# 2         Varun Chakaravarthy
# 8                     Not Out
# 14                    Not Out
# 18              Joshua Little
# ...

# %%
# we can perform individuals coulmns aggregate () also like=team ,runs etc
ipl1.get_group('Shikhar Dhawan')[['Fours','Sixes']].sum()
# Out:
# Fours    49
# Sixes    12
# dtype: int64

# %%
# we can calculate overall runs  fours sixes and ball 
ipl1.get_group('Shikhar Dhawan')[['Fours','Sixes','Ball','Run']].sum()
# Out:
# Fours     49
# Sixes     12
# Ball     261
# Run      373
# dtype: int64

# %%
# instead of apply one by one aggregate () we can pass list of aggregate methods 
# we will see more in detal in the aggregate heading 
ipl1.get_group('Shikhar Dhawan').aggregate(['min',  max])
# Out:
#             Batsman          team  Run  Ball  Fours  Sixes  \
# min  Shikhar Dhawan  Punjab Kings    0     1      0      0
# max  Shikhar Dhawan  Punjab Kings   99    66     12      5
#
#          Wicket taken by
# min           Adam Zampa
# max  Varun Chakaravarthy

# %%
# see the virat  kohli data
ipl1.get_group('Virat Kohli')
# Out:
#               Batsman                         team  Run  Ball  Fours  Sixes  \
# match_no
# 5         Virat Kohli  Royal Challengers Bangalore   82    49      6      5
# 9         Virat Kohli  Royal Challengers Bangalore   21    18      3      0
# 15        Virat Kohli  Royal Challengers Bangalore   61    44      4      4
# 20        Virat Kohli  Royal Challengers Bangalore   50    34      6      1
# 24        Virat Kohli  Royal Challengers Bangalore    6     4      1      0
# 27        Virat Kohli  Royal Challengers Bangalore   59    47      5      1
# 32        Virat Kohli  Royal Challengers Bangalore    0     1      0      0
# 36        Virat Kohli  Royal Challengers Bangalore   54    37      6      0
# 43        Virat Kohli  Royal Challengers Bangalore   31    30      3      0
# 50        Virat Kohli  Royal Challengers Bangalore   55    46      5      0
# 54        Virat Kohli  Royal Challengers Bangalore    1     4      0      0
# ...

# %%
ipl1.get_group('Virat Kohli')[['Run','Fours','Sixes']].sum()
# Out:
# Run      639
# Fours     65
# Sixes     16
# dtype: int64

# %%
ipl1.get_group('Virat Kohli')
# Out:
#               Batsman                         team  Run  Ball  Fours  Sixes  \
# match_no
# 5         Virat Kohli  Royal Challengers Bangalore   82    49      6      5
# 9         Virat Kohli  Royal Challengers Bangalore   21    18      3      0
# 15        Virat Kohli  Royal Challengers Bangalore   61    44      4      4
# 20        Virat Kohli  Royal Challengers Bangalore   50    34      6      1
# 24        Virat Kohli  Royal Challengers Bangalore    6     4      1      0
# 27        Virat Kohli  Royal Challengers Bangalore   59    47      5      1
# 32        Virat Kohli  Royal Challengers Bangalore    0     1      0      0
# 36        Virat Kohli  Royal Challengers Bangalore   54    37      6      0
# 43        Virat Kohli  Royal Challengers Bangalore   31    30      3      0
# 50        Virat Kohli  Royal Challengers Bangalore   55    46      5      0
# 54        Virat Kohli  Royal Challengers Bangalore    1     4      0      0
# ...

# %%
# getting all the stats of one specific player i.e Virat Kohli
ipl1.get_group('Virat Kohli').describe()
# Out:
#               Run       Ball      Fours      Sixes
# count   14.000000  14.000000  14.000000  14.000000
# mean    45.642857  32.642857   4.642857   1.142857
# std     34.154867  20.712713   3.973124   1.791310
# min      0.000000   1.000000   0.000000   0.000000
# 25%     18.750000  18.250000   1.500000   0.000000
# 50%     52.000000  35.500000   4.500000   0.000000
# 75%     60.500000  46.750000   6.000000   1.000000
# max    101.000000  63.000000  13.000000   5.000000

# %%
ipl1.get_group('Virat Kohli').median()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12860\2142821655.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ipl1.get_group('Virat Kohli').median()
# Run      52.0
# Ball     35.5
# Fours     4.5
# Sixes     0.0
# dtype: float64

# %%
#seeing in the maximum fours by vk
ipl1.get_group('Virat Kohli')['Fours'].max()
# Out:
# 13

# %%
ipl1.count()
# Out:
#                   team  Run  Ball  Fours  Sixes  Wicket taken by
# Batsman
# Abdul Basith         1    1     1      1      1                1
# Abdul Samad          8    8     8      8      8                8
# Abhinav Manohar      6    6     6      6      6                6
# Abhishek Sharma     11   11    11     11     11               11
# Abishek Porel        4    4     4      4      4                4
# ...                ...  ...   ...    ...    ...              ...
# Wayne Parnell        1    1     1      1      1                1
# Wriddhiman Saha     14   14    14     14     14               14
# Yash Dhull           3    3     3      3      3                3
# Yashasvi Jaiswal    14   14    14     14     14               14
# Yudhvir Singh        2    2     2      2      2                2
#
# [176 rows x 6 columns]

# %% [markdown]
# # Display() function:-
#
# In display() it will gather your output at once place simply we have to pass all the variablbe in display()

# %%
# performing the display () to  see virat kohli and abhishek sharma data at one place 

display(ipl1.get_group('Virat Kohli'),ipl1.get_group('Abhishek Sharma'))
# Out:
#               Batsman                         team  Run  Ball  Fours  Sixes  \
# match_no
# 5         Virat Kohli  Royal Challengers Bangalore   82    49      6      5
# 9         Virat Kohli  Royal Challengers Bangalore   21    18      3      0
# 15        Virat Kohli  Royal Challengers Bangalore   61    44      4      4
# 20        Virat Kohli  Royal Challengers Bangalore   50    34      6      1
# 24        Virat Kohli  Royal Challengers Bangalore    6     4      1      0
# 27        Virat Kohli  Royal Challengers Bangalore   59    47      5      1
# 32        Virat Kohli  Royal Challengers Bangalore    0     1      0      0
# 36        Virat Kohli  Royal Challengers Bangalore   54    37      6      0
# 43        Virat Kohli  Royal Challengers Bangalore   31    30      3      0
# 50        Virat Kohli  Royal Challengers Bangalore   55    46      5      0
# 54        Virat Kohli  Royal Challengers Bangalore    1     4      0      0
# ...

# %%
# Seeing the vk and ms dhoni data at one place
display(ipl1.get_group('Virat Kohli'),ipl1.get_group('MS Dhoni'))
# Out:
#               Batsman                         team  Run  Ball  Fours  Sixes  \
# match_no
# 5         Virat Kohli  Royal Challengers Bangalore   82    49      6      5
# 9         Virat Kohli  Royal Challengers Bangalore   21    18      3      0
# 15        Virat Kohli  Royal Challengers Bangalore   61    44      4      4
# 20        Virat Kohli  Royal Challengers Bangalore   50    34      6      1
# 24        Virat Kohli  Royal Challengers Bangalore    6     4      1      0
# 27        Virat Kohli  Royal Challengers Bangalore   59    47      5      1
# 32        Virat Kohli  Royal Challengers Bangalore    0     1      0      0
# 36        Virat Kohli  Royal Challengers Bangalore   54    37      6      0
# 43        Virat Kohli  Royal Challengers Bangalore   31    30      3      0
# 50        Virat Kohli  Royal Challengers Bangalore   55    46      5      0
# 54        Virat Kohli  Royal Challengers Bangalore    1     4      0      0
# ...

# %%
ipl1['Run'].describe().head()
# Out:
#                  count       mean        std  min    25%   50%    75%   max
# Batsman
# Abdul Basith       1.0   1.000000        NaN  1.0   1.00   1.0   1.00   1.0
# Abdul Samad        8.0  21.125000  11.179541  4.0  15.00  21.0  29.00  37.0
# Abhinav Manohar    6.0  19.000000  15.569200  2.0   5.75  20.0  26.75  42.0
# Abhishek Sharma   11.0  20.454545  23.205015  0.0   4.50   9.0  33.00  67.0
# Abishek Porel      4.0   8.250000   8.220908  1.0   4.00   6.0  10.25  20.0

# %% [markdown]
# # Aggregate, filter, transform, apply

# %% [markdown]
# # Aggregate()
#
# As we already know the  gorupby aggregate () like  sum(),mean() and  etc.
#
# In groupby aggregate () method allows for even more flexibility. It can take
# a string, a function, or a list thereof, and compute all the aggregates at once place.
#
# Groupby aggregate () methed also allows to   pass a dictionary  to perform aggregate ().

# %%
# performing the  min,max,mean by passing  through string etc  using aggregate () 

ipl1.aggregate(['min','max','mean']).head()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12860\3606250454.py:3: FutureWarning: ['team', 'Wicket taken by'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   ipl1.aggregate(['min','max','mean']).head()
#                 Run                Ball                Fours                \
#                 min max       mean  min max       mean   min max      mean
# Batsman
# Abdul Basith      1   1   1.000000    1   1   1.000000     0   0  0.000000
# Abdul Samad       4  37  21.125000    3  32  16.000000     0   3  1.250000
# Abhinav Manohar   2  42  19.000000    3  33  13.833333     0   3  1.000000
# Abhishek Sharma   0  67  20.454545    2  36  14.272727     0  12  2.545455
# Abishek Porel     1  20   8.250000    3  11   7.750000     0   1  0.250000
#
#                 Sixes
#                   min max      mean
# Batsman
# Abdul Basith        0   0  0.000000
# ...

# %%
# performing the  min,max,mean by passing  through list etc  using aggregate () 
ipl1.aggregate([min,max,sum]).head()
# Out:
#                                 team                       \
#                                  min                  max
# Batsman
# Abdul Basith        Rajasthan Royals     Rajasthan Royals
# Abdul Samad      Sunrisers Hyderabad  Sunrisers Hyderabad
# Abhinav Manohar       Gujarat Titans       Gujarat Titans
# Abhishek Sharma  Sunrisers Hyderabad  Sunrisers Hyderabad
# Abishek Porel         Delhi Capitals       Delhi Capitals
#
#                                                                    Run      \
#                                                                sum min max
# Batsman
# Abdul Basith                                      Rajasthan Royals   1   1
# Abdul Samad      Sunrisers HyderabadSunrisers HyderabadSunriser...   4  37
# Abhinav Manohar  Gujarat TitansGujarat TitansGujarat TitansGuja...   2  42
# Abhishek Sharma  Sunrisers HyderabadSunrisers HyderabadSunriser...   0  67
# Abishek Porel    Delhi CapitalsDelhi CapitalsDelhi CapitalsDelh...   1  20
#
# ...

# %%
# performing the  min,max,mean by passing  through string,list etc  using aggregate () 
ipl1.aggregate(['min',max,sum]).head()
# Out:
#                                 team                       \
#                                  min                  max
# Batsman
# Abdul Basith        Rajasthan Royals     Rajasthan Royals
# Abdul Samad      Sunrisers Hyderabad  Sunrisers Hyderabad
# Abhinav Manohar       Gujarat Titans       Gujarat Titans
# Abhishek Sharma  Sunrisers Hyderabad  Sunrisers Hyderabad
# Abishek Porel         Delhi Capitals       Delhi Capitals
#
#                                                                    Run      \
#                                                                sum min max
# Batsman
# Abdul Basith                                      Rajasthan Royals   1   1
# Abdul Samad      Sunrisers HyderabadSunrisers HyderabadSunriser...   4  37
# Abhinav Manohar  Gujarat TitansGujarat TitansGujarat TitansGuja...   2  42
# Abhishek Sharma  Sunrisers HyderabadSunrisers HyderabadSunriser...   0  67
# Abishek Porel    Delhi CapitalsDelhi CapitalsDelhi CapitalsDelh...   1  20
#
# ...

# %%
ipl1.aggregate(['min',max,mean]).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 ipl1.aggregate(['min',max,mean]).head()
#
# NameError: name 'mean' is not defined

# %% [raw]
# Here when we pass string list then we can not excute mean as shown above its giving error if we import numpy then it will not give see below it will retun by imporing numpy library.

# %%
# performing the  min,max,mean by passing  through string,list etc  using aggregate ()
import numpy as np
ipl1.aggregate(['min',max,np.mean,np.median]).head()

# %% [markdown]
# # Groupby aggregate () methed also allows to   pass a dictionary  to perform aggregate ().

# %%
# passing the dictionary in aggregate () to perform sum artmetic operations
ipl1.aggregate({'Run':'mean',
                'Ball':'sum',
               'Fours':'median',
                'Sixes':'max',}).head()

# %%
# apply aggregate to the single batsman player through list

ipl1.get_group('Virat Kohli').aggregate(['min','max','mean']).head()

# %%
# apply aggregate to the single batsman player through dictionary 

ipl1.get_group('Virat Kohli').aggregate({'Run':'mean',
                                         'Ball':'sum',
                                         'Fours':'median',
                                         'Sixes':'max'}).head()

# %%
# by passing the dictionary 
ipl1.get_group('Virat Kohli').aggregate({'Run':['mean','max',sum,'median','mean']})

# %% [markdown]
# # Filtering
#
# Filtering. A filtering operation allows you to drop data based on the group properties.
#
# Basically it drop the False value and return the True boolean value only.
#
# For example suppose  we are performing the addition task of two numbers and want to filter according to its value .
#  a=4+5=9 and b=5+3=8 by adding these the value of is a=9 ,b=8
#
# if the we filter according to which  is greater then  a or b by applying filter (), then it will only filter which one is greater number simply it will filter a value of a variable  that is 9 and drop the value of b that 8 which is not greater thrn a
# thats how filter works

# %% [raw]
# For filtering we make  define function or use lambda function  and pass it in the filter() because the data is in huge

# %%
# showing  the dataset
ipl1.head()
# Out:
#                     Batsman                         team  Run  Ball  Fours  \
# match_no
# 1              Devon Conway          Chennai Super Kings    1     6      0
# 1           Ruturaj Gaikwad          Chennai Super Kings   92    50      4
# 1                 Moeen Ali          Chennai Super Kings   23    17      4
# 1                Ben Stokes          Chennai Super Kings    7     6      1
# 1             Ambati Rayudu          Chennai Super Kings   12    12      0
# ...                     ...                          ...  ...   ...    ...
# 69           Vivrant Sharma          Sunrisers Hyderabad   69    47      9
# 69           Glenn Phillips          Sunrisers Hyderabad    1     4      0
# 69             Sanvir Singh          Sunrisers Hyderabad    4     3      1
# 70        Michael Bracewell  Royal Challengers Bangalore   26    16      5
# 70            Dasun Shanaka               Gujarat Titans    0     3      0
#
#           Sixes Wicket taken by
# match_no
# ...

# %%
# seeing which player has scored  run less then 1 run.
def oye(d):
    return d['Run'].sum()<1

# %%
# passing the oye function into the filter ()

w=ipl1.filter(oye)
w
# Out:
#                    Batsman                   team  Run  Ball  Fours  Sixes  \
# match_no
# 10        Romario Shepherd   Lucknow Super Giants    0     1      0      0
# 14            Rahul Chahar           Punjab Kings    0     8      0      0
# 15              Avesh Khan   Lucknow Super Giants    0     1      0      0
# 21           Kagiso Rabada           Punjab Kings    0     1      0      0
# 35          Riley Meredith         Mumbai Indians    0     2      0      0
# 38            Rahul Chahar           Punjab Kings    0     1      0      0
# 38           Kagiso Rabada           Punjab Kings    0     1      0      0
# 47            Harshit Rana  Kolkata Knight Riders    0     1      0      0
# 55        Tushar Deshpande    Chennai Super Kings    0     1      0      0
# 60                 KM Asif       Rajasthan Royals    0     2      0      0
# 62          Mohammed Shami         Gujarat Titans    0     1      0      0
# ...

# %% [raw]
# Above data shows run less than 1
#
# In  groupby filter  we can apply only aggregate to filter the data  and it give True boolean values only that mean whatever value is true after appplying the gaggregate it will show.

# %%
# taking the  sum of the  ball by 
def hey(t):
     return t['Ball'].sum()>120

# %%
# passing the hey function into the filter ()
d=ipl1.filter(hey)
d
# Out:
#                   Batsman                         team  Run  Ball  Fours  \
# match_no
# 1            Devon Conway          Chennai Super Kings    1     6      0
# 1         Ruturaj Gaikwad          Chennai Super Kings   92    50      4
# 1             Shivam Dube          Chennai Super Kings   19    18      0
# 1         Wriddhiman Saha               Gujarat Titans   25    16      2
# 1            Shubman Gill               Gujarat Titans   63    36      6
# ...                   ...                          ...  ...   ...    ...
# 70          Glenn Maxwell  Royal Challengers Bangalore   11     5      1
# 70        Wriddhiman Saha               Gujarat Titans   12    14      2
# 70           Shubman Gill               Gujarat Titans  104    52      5
# 70          Vijay Shankar               Gujarat Titans   53    35      7
# 70           David Miller               Gujarat Titans    6     7      1
#
#           Sixes         Wicket taken by
# match_no
# ...

# %%
# seeing which batsman has delevered 69 fours in the 2023 ipl season and in which match_no. has score how much fours
def see(g):
    return g['Fours'].sum()==69

# %%
dsa=ipl1.filter(see)
dsa
# Out:
#                Batsman            team  Run  Ball  Fours  Sixes  \
# match_no
# 3         David Warner  Delhi Capitals   56    48      7      0
# 7         David Warner  Delhi Capitals   37    32      7      0
# 11        David Warner  Delhi Capitals   65    55      7      0
# 16        David Warner  Delhi Capitals   51    47      6      0
# 20        David Warner  Delhi Capitals   19    13      4      0
# 28        David Warner  Delhi Capitals   57    41     11      0
# 34        David Warner  Delhi Capitals   21    20      2      1
# 40        David Warner  Delhi Capitals    0     2      0      0
# 44        David Warner  Delhi Capitals    2     2      0      0
# 50        David Warner  Delhi Capitals   22    14      3      1
# 55        David Warner  Delhi Capitals    0     2      0      0
# 59        David Warner  Delhi Capitals   54    27     10      1
# 64        David Warner  Delhi Capitals   46    31      5      2
# ...

# %%
# seeing the total no.  of fours
dsa['Fours'].sum()
# Out:
# 69

# %%
# seeing the maximum fours delevere by batsman from the above dsa variable
dsa['Fours'].max()
# Out:
# 11

# %%
# fetching all the sixes beaten by faf 
sa=ipl1.filter(lambda x: x['Sixes'].sum()>35)
sa
# Out:
#                  Batsman                         team  Run  Ball  Fours  \
# match_no
# 5         Faf du Plessis  Royal Challengers Bangalore   73    43      5
# 9         Faf du Plessis  Royal Challengers Bangalore   23    12      2
# 15        Faf du Plessis  Royal Challengers Bangalore   79    46      5
# 20        Faf du Plessis  Royal Challengers Bangalore   22    16      3
# 24        Faf du Plessis  Royal Challengers Bangalore   62    33      5
# 27        Faf du Plessis  Royal Challengers Bangalore   84    56      5
# 32        Faf du Plessis  Royal Challengers Bangalore   62    39      8
# 36        Faf du Plessis  Royal Challengers Bangalore   17     7      1
# 43        Faf du Plessis  Royal Challengers Bangalore   44    40      1
# 50        Faf du Plessis  Royal Challengers Bangalore   45    32      5
# 54        Faf du Plessis  Royal Challengers Bangalore   65    41      5
# 60        Faf du Plessis  Royal Challengers Bangalore   55    44      3
# ...

# %%
ipl1['Sixes'].sum().sort_values(ascending=False)
# Out:
# Batsman
# Faf du Plessis     36
# Shivam Dube        33
# Glenn Maxwell      31
# Rinku Singh        29
# Ruturaj Gaikwad    29
#                    ..
# Kedar Jadhav        0
# Karn Sharma         0
# Karan Sharma        0
# Kagiso Rabada       0
# Yudhvir Singh       0
# Name: Sixes, Length: 176, dtype: int64

# %%
# seeing both data at once place only 
display(ipl1['Sixes'].sum().sort_values(ascending=False),sa)
# Out:
# Batsman
# Faf du Plessis     36
# Shivam Dube        33
# Glenn Maxwell      31
# Rinku Singh        29
# Ruturaj Gaikwad    29
#                    ..
# Kedar Jadhav        0
# Karn Sharma         0
# Karan Sharma        0
# Kagiso Rabada       0
# Yudhvir Singh       0
# Name: Sixes, Length: 176, dtype: int64
#                  Batsman                         team  Run  Ball  Fours  \
# match_no
# 5         Faf du Plessis  Royal Challengers Bangalore   73    43      5
# 9         Faf du Plessis  Royal Challengers Bangalore   23    12      2
# 15        Faf du Plessis  Royal Challengers Bangalore   79    46      5
# 20        Faf du Plessis  Royal Challengers Bangalore   22    16      3
# 24        Faf du Plessis  Royal Challengers Bangalore   62    33      5
# 27        Faf du Plessis  Royal Challengers Bangalore   84    56      5
# 32        Faf du Plessis  Royal Challengers Bangalore   62    39      8
# 36        Faf du Plessis  Royal Challengers Bangalore   17     7      1
# ...

# %% [markdown]
# # Transformation/ Transform()
#
#
#
# In transformation  if you want to get a new value for each original row, use tranform()  function .
#
# Basically it put your desired output into your  each original dataset  input  rows  thats how it work like.
#
# As name suggesting it will tranformation can return some transformed version of the full data to recombine and  the output is the same shape as the input.
#
# For example suppose you have small data set of two rows and two columns and have performed sum() aggregation get your desired output  and you want to fill these output  value in the same dataframe without reducing it shape that is rows and columns in the dataset  then you can easily fill by  using these transfrom() methods

# %%
# calling the ipl1 dataset 
ipl1.head()
# Out:
#                     Batsman                         team  Run  Ball  Fours  \
# match_no
# 1              Devon Conway          Chennai Super Kings    1     6      0
# 1           Ruturaj Gaikwad          Chennai Super Kings   92    50      4
# 1                 Moeen Ali          Chennai Super Kings   23    17      4
# 1                Ben Stokes          Chennai Super Kings    7     6      1
# 1             Ambati Rayudu          Chennai Super Kings   12    12      0
# ...                     ...                          ...  ...   ...    ...
# 69           Vivrant Sharma          Sunrisers Hyderabad   69    47      9
# 69           Glenn Phillips          Sunrisers Hyderabad    1     4      0
# 69             Sanvir Singh          Sunrisers Hyderabad    4     3      1
# 70        Michael Bracewell  Royal Challengers Bangalore   26    16      5
# 70            Dasun Shanaka               Gujarat Titans    0     3      0
#
#           Sixes Wicket taken by
# match_no
# ...

# %%
# fetching all records of the one batsman  Devon Conway
ipl1.get_group('Devon Conway')
# Out:
#                Batsman                 team  Run  Ball  Fours  Sixes  \
# match_no
# 1         Devon Conway  Chennai Super Kings    1     6      0      0
# 6         Devon Conway  Chennai Super Kings   47    29      5      2
# 12        Devon Conway  Chennai Super Kings    0     4      0      0
# 17        Devon Conway  Chennai Super Kings   50    38      6      0
# 24        Devon Conway  Chennai Super Kings   83    45      6      6
# 33        Devon Conway  Chennai Super Kings   56    40      4      3
# 37        Devon Conway  Chennai Super Kings    8    16      1      0
# 41        Devon Conway  Chennai Super Kings   92    52     16      1
# 49        Devon Conway  Chennai Super Kings   44    42      4      0
# 55        Devon Conway  Chennai Super Kings   10    13      1      0
# 61        Devon Conway  Chennai Super Kings   30    28      3      0
# 67        Devon Conway  Chennai Super Kings   87    52     11      3
#
#               Wicket taken by
# match_no
# ...

# %%
# fetching all records of the one batsman  Devon Conway and taking its mean()
ipl1.get_group('Devon Conway').mean()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12860\820096279.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ipl1.get_group('Devon Conway').mean()
# Run      42.333333
# Ball     30.416667
# Fours     4.750000
# Sixes     1.250000
# dtype: float64

# %% [raw]
# Doing the above task is veru tedious show to see all the mean() in the original data set we can use tranform () instead of doin one by one .

# %%
# performing the mean of  using transpose () at ipl1
ipl1.transform(lambda x: x.mean())
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12860\1126478881.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.transform is deprecated. In a future version, a TypeError will be raised. Before calling .transform, select only columns which should be valid for the function.
#   ipl1.transform(lambda x: x.mean())
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12860\1126478881.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.transform is deprecated. In a future version, a TypeError will be raised. Before calling .transform, select only columns which should be valid for the function.
#   ipl1.transform(lambda x: x.mean())
#                 Run       Ball     Fours     Sixes
# match_no
# 1         42.333333  30.416667  4.750000  1.250000
# 1         41.500000  28.357143  3.428571  2.071429
# 1         12.777778   9.666667  1.333333  0.555556
# 1          7.500000   7.000000  1.000000  0.000000
# 1         12.200000   9.600000  0.800000  0.600000
# ...

# %% [raw]
# In the above we can see the mean of the ipl1 dataset
#
# Basically it adds all the run of player who played matcgh _no 1, and divide this by total inning or numbe rof match  played by the player and given the output as always mean() do.
#
# We are performing the huge amount of data so there might be little confusion while performing the transform method() as learning level.

# %%
# performing the max() of  using transpose () at ipl1 
ipl1.transform(lambda x: x.max())
# Out:
#                          team  Run Ball Fours Sixes      Wicket taken by
# match_no
# 1         Chennai Super Kings   92   52    16     6     Yuzvendra Chahal
# 1         Chennai Super Kings   92   57    12     9  Varun Chakaravarthy
# 1         Chennai Super Kings   23   17     4     2         Sunil Narine
# 1         Chennai Super Kings    8    8     1     0          Rashid Khan
# 1         Chennai Super Kings   27   17     3     2     Yuzvendra Chahal
# ...                       ...  ...  ...   ...   ...                  ...
# 70             Gujarat Titans  104   58    13     8     Yuzvendra Chahal
# 70             Gujarat Titans   63   35     7     5    Vijaykumar Vyshak
# 70             Gujarat Titans    9    7     1     0              Not Out
# 70             Gujarat Titans   46   30     4     4          T Natarajan
# 70             Gujarat Titans   20   14     1     3        Piyush Chawla
#
# [1114 rows x 6 columns]

# %% [markdown]
# # The apply() method.
#
# In these method basically we can apply our user define function or lamda and pass it to apply method().
#
# The function should take a DataFrame, and return either a Pandas
# object (e.g., DataFrame, Series) or a scalar; the combine operation will be tailored to
# the type of output returned.

# %%
# calling the ipl1 datasset 
ipl1.head()
# Out:
#                     Batsman                         team  Run  Ball  Fours  \
# match_no
# 1              Devon Conway          Chennai Super Kings    1     6      0
# 1           Ruturaj Gaikwad          Chennai Super Kings   92    50      4
# 1                 Moeen Ali          Chennai Super Kings   23    17      4
# 1                Ben Stokes          Chennai Super Kings    7     6      1
# 1             Ambati Rayudu          Chennai Super Kings   12    12      0
# ...                     ...                          ...  ...   ...    ...
# 69           Vivrant Sharma          Sunrisers Hyderabad   69    47      9
# 69           Glenn Phillips          Sunrisers Hyderabad    1     4      0
# 69             Sanvir Singh          Sunrisers Hyderabad    4     3      1
# 70        Michael Bracewell  Royal Challengers Bangalore   26    16      5
# 70            Dasun Shanaka               Gujarat Titans    0     3      0
#
#           Sixes Wicket taken by
# match_no
# ...

# %%
# applying() the function to get ball.sum
def he(x):
    x['Ball'].sum()
    return x

# %%
ipl1.apply(he)
# Out:
#                   Batsman                         team  Run  Ball  Fours  \
# match_no
# 1           Ambati Rayudu          Chennai Super Kings   12    12      0
# 1              Ben Stokes          Chennai Super Kings    7     6      1
# 1            Devon Conway          Chennai Super Kings    1     6      0
# 1           Hardik Pandya               Gujarat Titans    8    11      0
# 1                MS Dhoni          Chennai Super Kings   14     7      1
# ...                   ...                          ...  ...   ...    ...
# 70          Rahul Tewatia               Gujarat Titans    4     5      0
# 70           Shubman Gill               Gujarat Titans  104    52      5
# 70          Vijay Shankar               Gujarat Titans   53    35      7
# 70            Virat Kohli  Royal Challengers Bangalore  101    61     13
# 70        Wriddhiman Saha               Gujarat Titans   12    14      2
#
#           Sixes    Wicket taken by
# match_no
# ...

# %% [markdown]
# ## conculsion:
#
#
#
# when  to use all this function
#
# if we want to get a single value for each group -> use aggregate()
#
# if we want to get a subset of the input rows -> use filter()
#
# if we want to get a new value for each input row -> use transform()
